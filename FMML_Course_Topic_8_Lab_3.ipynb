# %% [markdown]
# <a href="https://colab.research.google.com/github/Laxmicharishma2005/FMML_LABS_PROJECS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 09:08:44--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   131MB/s    in 0.5s
#
# 2024-03-31 09:08:45 (131 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1359   1511.00363v3  Deep Neural Networks (DNN) have achieved state...    cs
# 12565  1803.00186v1  Semidefinite programs (SDP) are important in l...  stat
# 13007  1505.04085v1  Tensors play a central role in many modern mac...  stat
# 21448  1802.08365v2  Real-time bidding (RTB) is almost the most imp...    cs
# 31496  1803.05536v1  This paper investigates the evaluation of dens...    cs
# ...             ...                                                ...   ...
# 6068   1606.07365v1  Consider a number of workers running SGD indep...  stat
# 20330  1509.07582v1  We describe a framework for building abstracti...    cs
# 5896    1212.2504v1  Conditional Random Fields (CRFs) are undirecte...    cs
# 33550   0704.3268v1  An easily implementable path solution algorith...    cs
# 11082   1404.4175v1  Brain decoding is a data analysis paradigm for...  stat
#
#                                                    title  year  \
# 1359   BinaryConnect: Training Deep Neural Networks w...  2015
# 12565  Smoothed analysis for low-rank solutions to se...  2018
# 13007  Optimal Low-Rank Tensor Recovery from Separabl...  2015
# 21448  Budget Constrained Bidding by Model-free Reinf...  2018
# 31496  Evaluation of Dense 3D Reconstruction from 2D ...  2018
# ...                                                  ...   ...
# 6068             Parallel SGD: When does averaging help?  2016
# 20330  Constructing Abstraction Hierarchies Using a S...  2015
# 5896   Efficiently Inducing Features of Conditional R...  2012
# 33550  2D Path Solutions from a Single Layer Excitabl...  2007
# 11082                       MEG Decoding Across Subjects  2014
#
#                                                 keywords
# 1359   [breakthroughs, computational, computation, ap...
# 12565  [semidefinite, important, combinatorial, optim...
# 13007  [processing, applications, applications, expre...
# 21448  [important, mechanism, advertising, essential,...
# 31496  [investigates, evaluation, reconstruction, com...
# ...                                                  ...
# 6068   [independently, averaging, understood, averagi...
# 20330  [framework, abstraction, hierarchies, alternat...
# 5896   [conditional, undirected, graphical, correspon...
# 33550  [implementable, algorithm, excitableprogrammab...
# 11082  [neuroimaging, experiments, predicting, presen...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1359     [breakthroughs, computational, computation, ap...
# 12565    [semidefinite, important, combinatorial, optim...
# 13007    [processing, applications, applications, expre...
# 21448    [important, mechanism, advertising, essential,...
# 31496    [investigates, evaluation, reconstruction, com...
#                                ...
# 36559    [sequential, environments, partially, contextu...
# 11268    [parameter, estimation, particular, emphrieman...
# 21625    [estimation, typically, maximizing, objective,...
# 11408    [practical, approaches, isometric, embeddings,...
# 30504    [pixelwise, important, challenging, applicatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8754 words.
# Out of those 4535 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="613dae30-3566-4e38-a7a5-5530bf808bd7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("613dae30-3566-4e38-a7a5-5530bf808bd7")) {                    Plotly.newPlot(                        "613dae30-3566-4e38-a7a5-5530bf808bd7",                        [{"x":["accumulations","regularizer","constrained","specialized","computational","retaining","accumulated","dedicated","components","implementation","breakthroughs","introduce","operations","gradients","applications","replacing","computation","propagations","development","permutation","multipliers","accumulate","invariant","precision","constraints","quadratically","complexity","semidefinite","optimization","completion","important","approximate","combinatorial","solutions","appropriately","quadratic","algorithms","factorization","formulation","measurements","mechanisms","constitute","contractions","adaptation","decomposition","projections","computationally","motivates","separable","corresponds","reduction","experimentally","efficient","processing","expressed","methodology","logarithmic","theoretical","measurement","algorithm","mechanism","environment","appropriate","effectively","different","impressions","advertisers","challenges","performance","marketing","parameter","constraint","dynamically","framework","advertising","producing","behaviour","volatility","demonstrate","reinforcement","essential","experimental","formulate","exploration","sequentially","effectiveness","investigates","reconstruction","conference","evaluation","competitions","automatic","competition","recognition","resolution","organised","benchmark","convergence","correlation","numerical","simulated","estimated","parameters","established","stationary","generalized","estimating","underlying","multivariate","selection","covariance","segmentation","including","theoretically","practical","saturation","introduces","rigorously","assumptions","illustrate","phenomena","experiments","principled","instability","generative","adversarial","direction","understanding","substantiate","introducing","simultaneously","detection","announced","significantly","accuracies","frameworks","evaluated","classification","collaboration","similarity","knowledges","increases","developed","consisting","promising","efficiency","challenging","dermoscopic","pathologists","extraction","dermoscopy","challenge","convolutional","extremely","calculation","following","international","calculating","relationships","additional","initially","scientific","unification","resources","conceptual","associate","introduction","terminological","relations","initiative","organizing","structuring","quantifying","establish","autoencoders","enforcing","variational","consequences","independent","disentanglement","interpretable","autoencoder","consistent","discriminative","existence","controlling","available","representations","extension","predictable","disentangled","literature","knowledge","intensive","representation","instances","prediction","generalisation","therefore","modularity"],"y":[1,18,59,30,287,12,6,13,98,137,5,331,88,44,426,18,129,2,112,11,13,4,59,72,134,2,219,7,324,29,359,111,38,141,12,33,606,33,74,53,48,13,2,62,66,15,87,10,15,21,105,42,395,277,38,67,17,145,42,836,112,128,78,123,738,3,2,123,854,12,145,87,29,553,8,30,33,6,568,114,78,375,51,49,20,212,23,111,13,267,8,181,24,358,103,5,190,106,70,75,63,71,255,47,29,67,59,103,25,142,20,216,245,45,133,7,69,5,73,74,30,625,25,5,128,115,67,168,3,47,122,350,2,257,28,28,130,541,9,139,2,59,215,46,110,146,261,4,4,131,3,175,383,54,21,90,15,14,68,101,18,37,4,65,17,10,34,2,107,5,12,5,12,44,20,17,53,18,143,1,29,26,80,91,28,16,303,254,69,7,2,120,372,34,370,103,213,8,136,6],"type":"bar"},{"x":["accumulations","regularizer","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4535,), (4535, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8116666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>True</span> <span style=''>Online</span> <span style=''>Temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Difference</span> <span style=''>Learning</span> <br/><br/><span style=''>The</span> <span style=''>temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difference</span> <span style=''>methods</span> <span style=''>TD(lambda)</span> <span style=''>and</span> <span style=''>Sarsa(lambda)</span> <span style=''>form</span> <span style=''>a</span> <span style=''>core</span> <span style=''>part</span> <span style=''>of</span> <span style=''>modern</span> <span style='background-color:rgba(0, 255, 0, 0.47096774193548374);'>reinforcement</span> <span style=''>learning</span> <span style=''>Their</span> <span style=''>appeal</span> <span style=''>comes</span> <span style=''>from</span> <span style=''>their</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>and</span> <span style=''>their</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretation</span> <span style=''>given</span> <span style=''>by</span> <span style=''>their</span> <span style=''>forward</span> <span style=''>view</span> <span style=''>Recently</span> <span style=''>new</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>were</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>called</span> <span style=''>true</span> <span style=''>online</span> <span style=''>TD(lambda)</span> <span style=''>and</span> <span style=''>true</span> <span style=''>online</span> <span style=''>Sarsa(lambda)</span> <span style='background-color:rgba(0, 255, 0, 0.3666666666666666);'>respectively</span> <span style=''>(van</span> <span style=''>Seijen</span> <span style=''>Sutton</span> <span style=''>2014)</span> <span style=''>These</span> <span style=''>new</span> <span style=''>versions</span> <span style=''>maintain</span> <span style=''>an</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalence</span> <span style=''>with</span> <span style=''>the</span> <span style=''>forward</span> <span style=''>view</span> <span style=''>at</span> <span style=''>all</span> <span style=''>times</span> <span style=''>whereas</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>traditional</span> <span style=''>versions</span> <span style=''>only</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>it</span> <span style=''>for</span> <span style=''>small</span> <span style=''>step</span> <span style=''>sizes</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.7333333333333334);'>hypothesize</span> <span style=''>that</span> <span style=''>these</span> <span style=''>true</span> <span style=''>online</span> <span style=''>methods</span> <span style=''>not</span> <span style=''>only</span> <span style=''>have</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.34684684684684686);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>but</span> <span style=''>also</span> <span style=''>dominate</span> <span style=''>the</span> <span style=''>regular</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirically</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>put</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hypothesis</span> <span style=''>to</span> <span style=''>the</span> <span style=''>test</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Penalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Components</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>p</span> <span style=''>Small</span> <span style=''>n</span> <span style=''>Data</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>(POCRE)</span> <span style=''>for</span> <span style=''>large</span> <span style=''>p</span> <span style=''>small</span> <span style=''>n</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Orthogonal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequentially</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constructed</span> <span style=''>to</span> <span style=''>maximize</span> <span style=''>upon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>standardization</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>to</span> <span style=''>the</span> <span style=''>response</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>residuals</span> <span style=''>A</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>Bayes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>thresholding</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presented</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>identify</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>component</span> <span style=''>POCRE</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>owing</span> <span style=''>to</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>leading</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>principal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>components</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>offers</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>such</span> <span style=''>as</span> <span style=''>grouping</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>and</span> <span style=''>allowing</span> <span style=''>for</span> <span style=''>collinear</span> <span style=''>or</span> <span style=''>nearly</span> <span style=''>c ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.31264916467780435);'>Effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Dimensions</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchical</span> <span style=''>Latent</span> <span style=''>Class</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Hierarchical</span> <span style=''>latent</span> <span style=''>class</span> <span style=''>(HLC)</span> <span style=''>models</span> <span style=''>are</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>where</span> <span style=''>leaf</span> <span style=''>nodes</span> <span style=''>are</span> <span style=''>observed</span> <span style=''>while</span> <span style=''>internal</span> <span style=''>nodes</span> <span style=''>are</span> <span style=''>latent</span> <span style=''>There</span> <span style=''>are</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretically</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>justified</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>criteria</span> <span style=''>for</span> <span style=''>HLC</span> <span style=''>models</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>with</span> <span style=''>latent</span> <span style=''>nodes</span> <span style=''>in</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonetheless</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>studies</span> <span style=''>suggest</span> <span style=''>that</span> <span style=''>the</span> <span style=''>BIC</span> <span style=''>score</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4137931034482758);'>reasonable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>criterion</span> <span style=''>to</span> <span style=''>use</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>HLC</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>studies</span> <span style=''>also</span> <span style=''>suggest</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sometimes</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>can</span> <span style=''>be</span> <span style=''>improved</span> <span style=''>if</span> <span style=''>standard</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.36363636363636365);'>dimension</span> <span style=''>is</span> <span style=''>replaced</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.31264916467780435);'>effective</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.36363636363636365);'>dimension</span> <span style=''>in</span> <span style=''>the</span> <span style=''>penalty</span> <span style=''>term</span> <span style=''>of</span> <span style=''>the</span> <span style=''>BIC</span> <span style=''>score</span> <span style='background-color:rgba(0, 255, 0, 0.31264916467780435);'>Effective</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dimensions</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>In</span> <span style=''>this</span> <span style=''>pap ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Transforms</span> <span style=''>for</span> <span style=''>Small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Footprint</span> <span style=''>Deep</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>building</span> <span style=''>compact</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>pipelines</span> <span style=''>suitable</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deployment</span> <span style=''>on</span> <span style=''>storage</span> <span style=''>and</span> <span style=''>power</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>mobile</span> <span style=''>devices</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>broad</span> <span style=''>family</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>matrices</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterized</span> <span style=''>by</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>displacement</span> <span style=''>rank</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>admit</span> <span style=''>fast</span> <span style=''>function</span> <span style=''>and</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>and</span> <span style=''>span</span> <span style=''>a</span> <span style=''>rich</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>sharing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>configurations</span> <span style=''>whose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>modeling</span> <span style=''>capacity</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>tuned</span> <span style=''>along</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuum</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unstructured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>can</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style=''>forwardbackward</span> <span style=''>passes</span> <span style=''>during</span> <span style=''>training</span> <span style=''>and</span> <span style=''>offer</span> <span style=''>superior</span> <span style=''>accuracy</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09801840056617127)
# 	information (0.24805378627034677)
# 	experimental (0.1326963906581741)
# 	knowledge (0.1316348195329087)
# 	architecture (0.09589525831564048)
# 	segmentation (0.07643312101910828)
# 	detection (0.12384996461429583)
# 	different (0.2611464968152866)
# 	recognition (0.12668082094833688)
# 	convolutional (0.13552724699221513)
#
# Some Statistics words are:
# 	variational (0.10638297872340426)
# 	statistical (0.14792299898682879)
# 	stochastic (0.1403242147922999)
# 	theoretical (0.1514690982776089)
# 	algorithm (0.39868287740628167)
# 	estimation (0.1717325227963526)
# 	distribution (0.1884498480243161)
# 	dimensional (0.1833839918946302)
# 	inference (0.20212765957446807)
# 	regression (0.1838905775075988)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="108f4ed6-3828-496d-acc7-5f9a0f75e389" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("108f4ed6-3828-496d-acc7-5f9a0f75e389")) {                    Plotly.newPlot(                        "108f4ed6-3828-496d-acc7-5f9a0f75e389",                        [{"x":["accumulations","regularizer","constrained","specialized","computational","retaining","accumulated","dedicated","components","implementation","breakthroughs","introduce","operations","gradients","applications","replacing","computation","propagations","development","permutation","multipliers","accumulate","invariant","precision","constraints","quadratically","complexity","semidefinite","optimization","completion","important","approximate","combinatorial","solutions","appropriately","quadratic","algorithms","factorization","formulation","measurements","mechanisms","constitute","contractions","adaptation","decomposition","projections","computationally","motivates","separable","corresponds","reduction","experimentally","efficient","processing","expressed","methodology","logarithmic","theoretical","measurement","algorithm","mechanism","environment","appropriate","effectively","different","impressions","advertisers","challenges","performance","marketing","parameter","constraint","dynamically","framework","advertising","producing","behaviour","volatility","demonstrate","reinforcement","essential","experimental","formulate","exploration","sequentially","effectiveness","investigates","reconstruction","conference","evaluation","competitions","automatic","competition","recognition","resolution","organised","benchmark","convergence","correlation","numerical","simulated","estimated","parameters","established","stationary","generalized","estimating","underlying","multivariate","selection","covariance","segmentation","including","theoretically","practical","saturation","introduces","rigorously","assumptions","illustrate","phenomena","experiments","principled","instability","generative","adversarial","direction","understanding","substantiate","introducing","simultaneously","detection","announced","significantly","accuracies","frameworks","evaluated","classification","collaboration","similarity","knowledges","increases","developed","consisting","promising","efficiency","challenging","dermoscopic","pathologists","extraction","dermoscopy","challenge","convolutional","extremely","calculation","following","international","calculating","relationships","additional","initially","scientific","unification","resources","conceptual","associate","introduction","terminological","relations","initiative","organizing","structuring","quantifying","establish","autoencoders","enforcing","variational","consequences","independent","disentanglement","interpretable","autoencoder","consistent","discriminative","existence","controlling","available","representations","extension","predictable","disentangled","literature","knowledge","intensive","representation","instances","prediction","generalisation","therefore","modularity","presented","demonstrated","coevolution","embedding","evolutionary","dimension","providing","prohibitively","comparison","nonparametric","hierarchical","parametric","especially","nonparametrics","dirichlet","processes","hierachical","increasingly","inference","submodularity","allocation","flexibility","polynomial","simulation","statistical","uniformly","properties","elimination","situations","recursive","moderately","dimensions","partitions","considers","considered","asymmetric","construction","clustering","alternative","dissimilarities","furthermore","modifying","dissimilarity","represented","transformation","structure","reciprocal","clustered","particular","admissible","methodologies"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonparametrics
# 	sparsistent
# 	dobrushins
# 	stationarities
# 	bivariate
# 	nonstationarity
# 	borrowings
# 	dispersion
# 	additively
# 	parametrisation
# 	encapsulated
# 	equitability
# 	equitable
# 	timescales
# 	inclusions
# 	conjugacy
# 	diarization
# 	attainable
# 	archetypal
# 	archetypes
# Some words which never appear in Statistics papers:
# 	impressions
# 	announced
# 	knowledges
# 	dermoscopic
# 	dermoscopy
# 	unification
# 	terminological
# 	coevolution
# 	concluding
# 	prisoners
# 	declarative
# 	deliberately
# 	recognizer
# 	algorithmically
# 	compilation
# 	exclusiveness
# 	speculate
# 	deduction
# 	propositional
# 	valuations

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0492453117853333e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7483333333333333
